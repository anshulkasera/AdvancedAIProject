# %% [markdown]
# <a href="https://colab.research.google.com/github/anshulkasera/AdvancedAIProject/blob/main/RLLLM_MultiEnv_Training_With_Image_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-Environment RLHF Notebook (Hopper + Pendulum)
#
# This notebook is organized as:
# 1. Shared definitions only (no training runs)
# 2. Environment-specific configs and prompt styles
# 3. Run cells for different experiment types

# %%
# Install required packages
# !pip install -q "gymnasium[mujoco]"
# !pip install -q -U transformers accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 771.8 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 75.4 MB/s eta 0:00:00

# %%
# ── Cell: install EGL support for headless MuJoCo rendering ───────────────────
# !apt-get install -y -qq libegl1-mesa libgl1-mesa-glx libglfw3

import os
os.environ["MUJOCO_GL"] = "egl"
os.environ["PYOPENGL_PLATFORM"] = "egl"

print("EGL configured. Now restart the runtime and run all cells again.")
print("Runtime → Restart session (or Ctrl+M .)")
# Out:
# Selecting previously unselected package libegl1-mesa:amd64.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../libegl1-mesa_23.0.4-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking libegl1-mesa:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package libglfw3:amd64.
# Preparing to unpack .../libglfw3_3.3.6-1_amd64.deb ...
# Unpacking libglfw3:amd64 (3.3.6-1) ...
# Setting up libglfw3:amd64 (3.3.6-1) ...
# Setting up libegl1-mesa:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# EGL configured. Now restart the runtime and run all cells again.
# Runtime → Restart session (or Ctrl+M .)

# %%
# ── verify headless rendering works ───────────────────────────────────────────
import os
os.environ["MUJOCO_GL"] = "egl"
os.environ["PYOPENGL_PLATFORM"] = "egl"

import gymnasium as gym
import numpy as np

test_env = gym.make("Hopper-v5", render_mode="rgb_array")
obs, _ = test_env.reset()
frame = test_env.render()
test_env.close()

print(f"✓ Headless rendering works")
print(f"  Frame shape: {frame.shape}")   # should be (H, W, 3)
print(f"  Frame dtype: {frame.dtype}")   # should be uint8
print(f"  Value range: [{frame.min()}, {frame.max()}]")
# Out:
# ✓ Headless rendering works
#   Frame shape: (480, 480, 3)
#   Frame dtype: uint8
#   Value range: [0, 255]

# %%
# Shared imports and global hyperparameters (definitions only)
import re
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Normal
import gymnasium as gym

# Model/training hyperparameters
HIDDEN_DIM = 128
LR_POLICY = 3e-4
LR_VALUE = 1e-3
LR_REWARD = 1e-3
GAMMA = 0.99
LAM = 0.95
PPO_EPOCHS = 4
CLIP_EPS = 0.2
VALUE_COEF = 0.5
ENTROPY_COEF = 0.01
MAX_GRAD_NORM = 0.5
SEGMENT_LENGTH = 50
ROLLOUT_STEPS = 2048
COMPARISONS_PER_ROUND = 20
RM_TRAIN_EPOCHS = 10

def set_global_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

def parse_preference_from_llm(raw: str):
    """Parse A/B preference from model output."""
    match = re.match(r"^\s*([AB])\b", raw, re.IGNORECASE)
    if match:
        preference = match.group(1).upper()
        explanation = raw[match.end():].strip().lstrip(".,:-")
        return preference, explanation

    letters = re.findall(r"\b([AB])\b", raw, re.IGNORECASE)
    preference = letters[0].upper() if letters else "UNCLEAR"
    return preference, raw

# %%
# Environment-specific configuration and prompt templates (definitions only)
ENV_CONFIGS = {
    "hopper": {
        "env_id": "Hopper-v5",
        "obs_dim": 11,
        "action_dim": 3,
        "forward_index": 5,
        "height_index": 0,
        "angle_index": 1,
        "healthy_height_min": 0.7,
        "healthy_angle_min": -0.2,
        "healthy_angle_max": 0.2,
        "terminated_can_mean_fall": True,
    },
    "pendulum": {
        "env_id": "Pendulum-v1",
        "obs_dim": 3,
        "action_dim": 1,
        "cos_index": 0,
        "sin_index": 1,
        "theta_dot_index": 2,
        "terminated_can_mean_fall": False,
        "upright_cos_threshold": 0.9,
        "still_theta_dot_threshold": 1.0,
    },
    "ant":{
        "env_id": "Ant-v5",
        "obs_dim": 27,
        "action_dim": 8,
        "x_velocity_index": 13,
        "z_height_index": 0,
        "healthy_height_min": 0.2,
        "healthy_height_max": 1.0,
        "terminated_can_mean_fall": True,
    }
}

PROMPT_STYLES_BY_ENV = {
    "hopper": {
        "balanced_goal_first": (
            "You are evaluating two Hopper trajectory segments.\n"
            "Goal: stay upright and balanced while moving forward.\n"
            "Healthy posture: torso height > {healthy_height_min:.2f} and torso angle in [{healthy_angle_min:.2f}, {healthy_angle_max:.2f}].\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Which segment is better overall?"
        ),
        "checklist_style": (
            "Evaluate Segment A and Segment B for Hopper.\n"
            "Checklist in order: (1) upright stability, (2) tilt control, (3) forward movement consistency.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Which segment should be preferred?"
        ),
        "minimal_stats_style": (
            "Choose the better Hopper segment for robust locomotion under noise.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Choose one."
        ),
    },
    "pendulum": {
        "balanced_goal_first": (
            "You are evaluating two Pendulum control segments.\n"
            "Goal: keep the pendulum upright with low angular velocity and smooth torque.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Which segment better achieves stable upright control?"
        ),
        "checklist_style": (
            "Evaluate Segment A and Segment B for Pendulum.\n"
            "Checklist: (1) uprightness, (2) low oscillation, (3) lower control effort.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Which segment is better?"
        ),
        "minimal_stats_style": (
            "Pick the segment with more stable upright behavior and less swinging.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Choose one."
        ),
    },
    "ant":{
        "balanced_goal_first": (
            "You are evaluating two Ant robot trajectory segments.\n"
            "Goal: move forward efficiently while maintaining stability (not falling).\n"
            "Healthy posture: torso height within a reasonable range.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Which segment is better overall?"
        ),
        "checklist_style": (
            "Evaluate Segment A and Segment B for Ant.\n"
            "Checklist: (1) stability (no falling), (2) forward movement, (3) smooth motion.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Which segment is better?"
        ),
        "minimal_stats_style": (
            "Pick the better Ant segment for stable forward locomotion.\n\n"
            "{desc_a}\n\n{desc_b}\n\n"
            "Choose one."
        ),
    }
}

OUTPUT_INSTRUCTION = "\n\nReturn ONLY: the letter A or B, then one short sentence explanation."

def make_env(env_name: str, seed: int = None):
    cfg = ENV_CONFIGS[env_name]
    env = gym.make(cfg["env_id"])
    if seed is not None:
        env.reset(seed=seed)
    return env, cfg

# %%
# Core models and preference buffer (definitions only)
class PolicyNetwork(nn.Module):
    def __init__(self, obs_dim, action_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, HIDDEN_DIM),
            nn.Tanh(),
            nn.Linear(HIDDEN_DIM, HIDDEN_DIM),
            nn.Tanh(),
        )
        self.mean_head = nn.Linear(HIDDEN_DIM, action_dim)
        self.log_std_head = nn.Linear(HIDDEN_DIM, action_dim)
        nn.init.orthogonal_(self.mean_head.weight, gain=0.01)
        nn.init.zeros_(self.mean_head.bias)

    def forward(self, obs):
        x = self.net(obs)
        mean = self.mean_head(x)
        log_std = self.log_std_head(x)
        log_std = torch.clamp(log_std, min=-2.0, max=0.5)
        std = torch.exp(log_std)
        return Normal(mean, std)

    def get_action(self, obs):
        obs_t = torch.FloatTensor(obs).unsqueeze(0)
        dist = self.forward(obs_t)
        action = dist.sample()
        log_prob = dist.log_prob(action).sum(dim=-1)
        entropy = dist.entropy().sum(dim=-1)
        action_np = action.squeeze(0).detach().numpy()
        action_np = np.clip(action_np, -1.0, 1.0)
        return action_np, log_prob, entropy

    def evaluate_actions(self, obs, actions):
        dist = self.forward(obs)
        log_probs = dist.log_prob(actions).sum(dim=-1)
        entropy = dist.entropy().sum(dim=-1)
        return log_probs, entropy


class ValueNetwork(nn.Module):
    def __init__(self, obs_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, HIDDEN_DIM),
            nn.Tanh(),
            nn.Linear(HIDDEN_DIM, HIDDEN_DIM),
            nn.Tanh(),
            nn.Linear(HIDDEN_DIM, 1),
        )
        nn.init.orthogonal_(self.net[-1].weight, gain=1.0)

    def forward(self, obs):
        return self.net(obs)


class RewardModel(nn.Module):
    def __init__(self, obs_dim, action_dim):
        super().__init__()
        input_dim = obs_dim + action_dim
        self.net = nn.Sequential(
            nn.Linear(input_dim, HIDDEN_DIM),
            nn.Tanh(),
            nn.Linear(HIDDEN_DIM, HIDDEN_DIM),
            nn.Tanh(),
            nn.Linear(HIDDEN_DIM, 1),
        )
        nn.init.orthogonal_(self.net[-1].weight, gain=1.0)

    def score_segment(self, obs_seq, act_seq):
        x = torch.cat([obs_seq, act_seq], dim=-1)
        return self.net(x).sum()

    def forward(self, obs_seq, act_seq):
        return self.score_segment(obs_seq, act_seq)


class ComparisonBuffer:
    def __init__(self):
        self.winners = []
        self.losers = []

    def __len__(self):
        return len(self.winners)

    def add(self, seg_a, seg_b, preference):
        if preference == "A":
            winner, loser = seg_a, seg_b
        elif preference == "B":
            winner, loser = seg_b, seg_a
        else:
            return

        self.winners.append((torch.FloatTensor(winner["observations"]), torch.FloatTensor(winner["actions"])))
        self.losers.append((torch.FloatTensor(loser["observations"]), torch.FloatTensor(loser["actions"])))

    def train_reward_model(self, reward_model, num_epochs=5, lr=1e-3):
        if len(self) == 0:
            return []

        optimizer = torch.optim.Adam(reward_model.parameters(), lr=lr)
        losses = []
        for _ in range(num_epochs):
            epoch_loss = 0.0
            for (win_obs, win_act), (lose_obs, lose_act) in zip(self.winners, self.losers):
                r_winner = reward_model.score_segment(win_obs, win_act)
                r_loser = reward_model.score_segment(lose_obs, lose_act)
                loss = -F.logsigmoid(r_winner - r_loser)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                epoch_loss += loss.item()

            losses.append(epoch_loss / len(self))

        return losses

# %%
# Segment stats, descriptions, prompts, rollout collection (definitions only)
def _pendulum_angle_from_obs(obs_arr, cfg):
    cos_th = obs_arr[:, cfg["cos_index"]]
    sin_th = obs_arr[:, cfg["sin_index"]]
    return np.arctan2(sin_th, cos_th)


def compute_segment_stats_env(obs_arr, act_arr, env_rewards, terminated_flag, cfg):
    seg = {
        "observations": obs_arr,
        "actions": act_arr,
        "segment_length": int(len(obs_arr)),
        "env_avg_reward": float(np.mean(env_rewards)) if len(env_rewards) else 0.0,
        "env_total_reward": float(np.sum(env_rewards)) if len(env_rewards) else 0.0,
    }

    if cfg["env_id"] == "Hopper-v5":
        h_idx = cfg["height_index"]
        a_idx = cfg["angle_index"]
        f_idx = cfg["forward_index"]
        healthy_height = obs_arr[:, h_idx] > cfg["healthy_height_min"]
        healthy_angle = (obs_arr[:, a_idx] >= cfg["healthy_angle_min"]) & (obs_arr[:, a_idx] <= cfg["healthy_angle_max"])
        seg.update({
            "fell": bool(terminated_flag),
            "time_upright": int(np.sum(healthy_height)),
            "avg_height": float(np.mean(obs_arr[:, h_idx])),
            "min_height": float(np.min(obs_arr[:, h_idx])),
            "max_height": float(np.max(obs_arr[:, h_idx])),
            "avg_angle": float(np.mean(obs_arr[:, a_idx])),
            "min_angle": float(np.min(obs_arr[:, a_idx])),
            "max_angle": float(np.max(obs_arr[:, a_idx])),
            "angle_healthy_pct": float(np.mean(healthy_angle) * 100.0),
            "avg_forward_metric": float(np.mean(obs_arr[:, f_idx])),
            "forward_metric_name": "avg_forward_velocity",
        })
    elif cfg["env_id"] == "Pendulum-v1":
        theta = _pendulum_angle_from_obs(obs_arr, cfg)
        theta_dot = obs_arr[:, cfg["theta_dot_index"]]
        upright = obs_arr[:, cfg["cos_index"]] >= cfg["upright_cos_threshold"]
        still = np.abs(theta_dot) <= cfg["still_theta_dot_threshold"]
        seg.update({
            "fell": False,
            "time_upright": int(np.sum(upright)),
            "avg_abs_angle": float(np.mean(np.abs(theta))),
            "max_abs_angle": float(np.max(np.abs(theta))),
            "avg_abs_theta_dot": float(np.mean(np.abs(theta_dot))),
            "still_pct": float(np.mean(still) * 100.0),
            "avg_forward_metric": float(-np.mean(np.abs(theta))),
            "forward_metric_name": "negative_abs_angle",
        })
    elif cfg["env_id"] == "Ant-v5":
        h_idx = cfg["z_height_index"]
        v_idx = cfg["x_velocity_index"]

        healthy_height = (
            (obs_arr[:, h_idx] > cfg["healthy_height_min"]) &
            (obs_arr[:, h_idx] < cfg["healthy_height_max"])
        )

        seg.update({
            "fell": bool(terminated_flag),
            "time_healthy": int(np.sum(healthy_height)),
            "avg_height": float(np.mean(obs_arr[:, h_idx])),
            "min_height": float(np.min(obs_arr[:, h_idx])),
            "max_height": float(np.max(obs_arr[:, h_idx])),
            "avg_forward_metric": float(np.mean(obs_arr[:, v_idx])),
            "forward_metric_name": "x_velocity",
        })
    else:
        raise ValueError(f"Unsupported env id: {cfg['env_id']}")

    return seg


def describe_segment_env(seg, cfg, label="A"):
    if cfg["env_id"] == "Hopper-v5":
        return (
            f"Segment {label} ({seg['segment_length']} steps):\n"
            f"- Fell: {seg['fell']}\n"
            f"- Upright steps: {seg['time_upright']}/{seg['segment_length']}\n"
            f"- Height avg/min/max: {seg['avg_height']:.3f}/{seg['min_height']:.3f}/{seg['max_height']:.3f}\n"
            f"- Angle avg/min/max: {seg['avg_angle']:.3f}/{seg['min_angle']:.3f}/{seg['max_angle']:.3f}\n"
            f"- Angle healthy %: {seg['angle_healthy_pct']:.1f}%\n"
            f"- Avg forward velocity: {seg['avg_forward_metric']:.3f}\n"
            f"- Env total reward: {seg['env_total_reward']:.3f}"
        )

    if cfg["env_id"] == "Pendulum-v1":
        return (
            f"Segment {label} ({seg['segment_length']} steps):\n"
            f"- Upright steps: {seg['time_upright']}/{seg['segment_length']}\n"
            f"- Avg |angle| (rad): {seg['avg_abs_angle']:.3f}\n"
            f"- Max |angle| (rad): {seg['max_abs_angle']:.3f}\n"
            f"- Avg |theta_dot|: {seg['avg_abs_theta_dot']:.3f}\n"
            f"- Stillness %: {seg['still_pct']:.1f}%\n"
            f"- Env total reward: {seg['env_total_reward']:.3f}"
        )
    if cfg["env_id"] == "Ant-v5":
        return (
            f"Segment {label} ({seg['segment_length']} steps):\n"
            f"- Fell: {seg['fell']}\n"
            f"- Healthy steps: {seg['time_healthy']}/{seg['segment_length']}\n"
            f"- Height avg/min/max: {seg['avg_height']:.3f}/{seg['min_height']:.3f}/{seg['max_height']:.3f}\n"
            f"- Avg forward velocity: {seg['avg_forward_metric']:.3f}\n"
            f"- Env total reward: {seg['env_total_reward']:.3f}"
        )
    raise ValueError(f"Unsupported env id: {cfg['env_id']}")


def build_pair_prompt(seg_a, seg_b, env_name, style_name):
    cfg = ENV_CONFIGS[env_name]
    styles = PROMPT_STYLES_BY_ENV[env_name]
    if style_name not in styles:
        raise ValueError(f"Unknown style '{style_name}' for env '{env_name}'")

    desc_a = describe_segment_env(seg_a, cfg, label="A")
    desc_b = describe_segment_env(seg_b, cfg, label="B")
    prompt = styles[style_name].format(desc_a=desc_a, desc_b=desc_b, **cfg)
    return prompt + OUTPUT_INSTRUCTION


def get_llm_preference_with_style(seg_a, seg_b, env_name, style_name, llm_query_fn, max_new_tokens=80):
    prompt = build_pair_prompt(seg_a, seg_b, env_name=env_name, style_name=style_name)
    raw = llm_query_fn(prompt, max_new_tokens=max_new_tokens)
    preference, explanation = parse_preference_from_llm(raw)
    return preference, explanation, raw


def collect_rollout(env, cfg, policy, value_net, reward_model=None, rollout_steps=ROLLOUT_STEPS, segment_length=SEGMENT_LENGTH):
    obs_list, act_list, logprob_list = [], [], []
    rm_reward_list, env_reward_list, value_list, done_list = [], [], [], []

    segments = []
    seg_obs, seg_act, seg_env_rewards = [], [], []

    obs, _ = env.reset()

    for _ in range(rollout_steps):
        obs_t = torch.FloatTensor(obs)
        with torch.no_grad():
            action_np, log_prob, _ = policy.get_action(obs)
            value = value_net(obs_t.unsqueeze(0)).squeeze()

        next_obs, env_reward, terminated, truncated, _ = env.step(action_np)
        done = bool(terminated or truncated)

        if reward_model is not None:
            with torch.no_grad():
                rm_reward = reward_model(
                    torch.FloatTensor(obs).unsqueeze(0),
                    torch.FloatTensor(action_np).unsqueeze(0),
                ).item()
        else:
            rm_reward = float(env_reward)

        obs_list.append(obs.copy())
        act_list.append(action_np.copy())
        logprob_list.append(log_prob.item())
        rm_reward_list.append(float(rm_reward))
        env_reward_list.append(float(env_reward))
        value_list.append(value.item())
        done_list.append(float(done))

        seg_obs.append(obs.copy())
        seg_act.append(action_np.copy())
        seg_env_rewards.append(float(env_reward))

        if len(seg_obs) == segment_length:
            segments.append(
                compute_segment_stats_env(
                    np.array(seg_obs),
                    np.array(seg_act),
                    np.array(seg_env_rewards),
                    terminated_flag=terminated,
                    cfg=cfg,
                )
            )
            seg_obs, seg_act, seg_env_rewards = [], [], []

        obs = next_obs
        if done:
            obs, _ = env.reset()

    return {
        "observations": np.array(obs_list),
        "actions": np.array(act_list),
        "logprobs": np.array(logprob_list),
        "rewards": np.array(rm_reward_list),
        "env_rewards": np.array(env_reward_list),
        "values": np.array(value_list),
        "dones": np.array(done_list, dtype=np.float32),
        "segments": segments,
    }

# %%
# PPO, training loops, and comparisons (definitions only)
def compute_gae(rewards, values, dones, gamma=GAMMA, lam=LAM):
    advantages = []
    gae = 0.0
    for t in reversed(range(len(rewards))):
        next_value = 0.0 if t == len(rewards) - 1 else values[t + 1]
        delta = rewards[t] + gamma * next_value * (1 - dones[t]) - values[t]
        gae = delta + gamma * lam * gae * (1 - dones[t])
        advantages.insert(0, gae)

    advantages = torch.FloatTensor(advantages)
    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
    returns = advantages + torch.FloatTensor(values)
    return advantages, returns


def ppo_update(policy, value_net, obs_batch, act_batch, old_logprobs, advantages, returns, ppo_epochs=PPO_EPOCHS, clip_eps=CLIP_EPS):
    policy_optimizer = torch.optim.Adam(policy.parameters(), lr=LR_POLICY)
    value_optimizer = torch.optim.Adam(value_net.parameters(), lr=LR_VALUE)

    obs_t = torch.FloatTensor(obs_batch)
    act_t = torch.FloatTensor(act_batch)
    old_lp_t = torch.FloatTensor(old_logprobs)

    for _ in range(ppo_epochs):
        new_log_probs, entropy = policy.evaluate_actions(obs_t, act_t)
        ratio = torch.exp(new_log_probs - old_lp_t)
        surr1 = ratio * advantages
        surr2 = torch.clamp(ratio, 1.0 - clip_eps, 1.0 + clip_eps) * advantages

        policy_loss = -torch.min(surr1, surr2).mean()
        entropy_loss = -ENTROPY_COEF * entropy.mean()
        policy_objective = policy_loss + entropy_loss

        policy_optimizer.zero_grad()
        policy_objective.backward()
        torch.nn.utils.clip_grad_norm_(policy.parameters(), MAX_GRAD_NORM)
        policy_optimizer.step()

        value_pred = value_net(obs_t).squeeze()
        value_loss = F.mse_loss(value_pred, returns)

        value_optimizer.zero_grad()
        value_loss.backward()
        torch.nn.utils.clip_grad_norm_(value_net.parameters(), MAX_GRAD_NORM)
        value_optimizer.step()


# Add-on evaluation: episode survival duration (in addition to current rollout metrics)
# Only environments listed here will collect survival metrics.
SURVIVAL_METRIC_ENVS = {'hopper', 'ant'}


def evaluate_episode_length_until_done(env, policy, num_episodes=10, max_steps=None):
    """Measure per-episode survival length until terminated/truncated (or optional max_steps cap)."""
    episode_lengths = []

    for _ in range(num_episodes):
        obs, _ = env.reset()
        steps = 0

        while True:
            with torch.no_grad():
                action_np, _, _ = policy.get_action(obs)

            obs, _, terminated, truncated, _ = env.step(action_np)
            steps += 1

            reached_user_cap = (max_steps is not None and steps >= max_steps)
            if terminated or truncated or reached_user_cap:
                break

        episode_lengths.append(steps)

    if not episode_lengths:
        return {
            'episode_length_mean': 0.0,
            'episode_length_median': 0.0,
            'episode_length_max': 0,
            'episode_length_min': 0,
            'episode_length_std': 0.0,
            'survival_eval_episodes': 0,
        }

    arr = np.array(episode_lengths, dtype=np.float32)
    return {
        'episode_length_mean': float(np.mean(arr)),
        'episode_length_median': float(np.median(arr)),
        'episode_length_max': int(np.max(arr)),
        'episode_length_min': int(np.min(arr)),
        'episode_length_std': float(np.std(arr)),
        'survival_eval_episodes': int(len(episode_lengths)),
    }


def add_survival_metrics_to_row(row, env_name, env, policy, survival_eval_episodes=10, survival_max_steps=None):
    """Attach survival keys to every round row for consistent data_points schema."""
    row['survival_metrics_collected'] = False
    row['episode_length_mean'] = None
    row['episode_length_median'] = None
    row['episode_length_max'] = None
    row['episode_length_min'] = None
    row['episode_length_std'] = None
    row['survival_eval_episodes'] = 0

    if env_name in SURVIVAL_METRIC_ENVS:
        row.update(
            evaluate_episode_length_until_done(
                env,
                policy,
                num_episodes=survival_eval_episodes,
                max_steps=survival_max_steps,
            )
        )
        row['survival_metrics_collected'] = True



def training_loop_no_llm(
    env, cfg, policy, value_net, num_rounds=5, rollout_steps=ROLLOUT_STEPS,
    env_name='unknown', prompt_style='unknown', phase_name='warmup', timestep_offset=0,
    survival_eval_episodes=10, survival_max_steps=None,
):
    history = []
    for round_idx in range(num_rounds):
        rollout = collect_rollout(env, cfg, policy, value_net, reward_model=None, rollout_steps=rollout_steps)
        advantages, returns = compute_gae(rollout['rewards'], rollout['values'], rollout['dones'])
        ppo_update(
            policy, value_net,
            rollout['observations'], rollout['actions'], rollout['logprobs'],
            advantages, returns,
        )

        timestep_end = timestep_offset + (round_idx + 1) * rollout_steps
        avg_env_reward = float(np.mean(rollout['env_rewards'])) if len(rollout['env_rewards']) else 0.0

        row = {
            'env_name': env_name,
            'prompt_style': prompt_style,
            'phase': phase_name,
            'round': round_idx + 1,
            'global_round': round_idx + 1,
            'timesteps_this_round': int(rollout_steps),
            'timestep_end': int(timestep_end),
            'avg_env_reward': avg_env_reward,
            'avg_reward_model_score': float(np.mean(rollout['rewards'])) if len(rollout['rewards']) else 0.0,
            'segments_collected': len(rollout['segments']),
            'new_comparisons': 0,
            'unclear_responses': 0,
            'buffer_size': 0,
            'rm_final_loss': None,
        }
        add_survival_metrics_to_row(
            row,
            env_name=env_name,
            env=env,
            policy=policy,
            survival_eval_episodes=survival_eval_episodes,
            survival_max_steps=survival_max_steps,
        )

        history.append(row)
        print(f'Baseline round {round_idx + 1}/{num_rounds} complete')

    return history


def training_loop_with_prompt_style(
    env, cfg, env_name, policy, value_net, reward_model, buffer, prompt_style, llm_query_fn,
    num_rounds=5, rollout_steps=ROLLOUT_STEPS, phase_name='rlhf', timestep_offset=0,
    global_round_offset=0, survival_eval_episodes=10, survival_max_steps=None,
):
    history = []
    for round_idx in range(num_rounds):
        rollout = collect_rollout(env, cfg, policy, value_net, reward_model=reward_model, rollout_steps=rollout_steps)
        segments = rollout['segments']

        new_comparisons = 0
        unclear = 0

        for _ in range(COMPARISONS_PER_ROUND):
            if len(segments) < 2:
                break
            idx_a, idx_b = np.random.choice(len(segments), size=2, replace=False)
            seg_a, seg_b = segments[idx_a], segments[idx_b]
            preference, _, _ = get_llm_preference_with_style(
                seg_a, seg_b, env_name=env_name, style_name=prompt_style, llm_query_fn=llm_query_fn
            )
            if preference in ['A', 'B']:
                buffer.add(seg_a, seg_b, preference)
                new_comparisons += 1
            else:
                unclear += 1

        rm_final = None
        if len(buffer) >= 5:
            rm_losses = buffer.train_reward_model(reward_model, num_epochs=RM_TRAIN_EPOCHS, lr=LR_REWARD)
            rm_final = rm_losses[-1] if rm_losses else None

        advantages, returns = compute_gae(rollout['rewards'], rollout['values'], rollout['dones'])
        ppo_update(
            policy, value_net,
            rollout['observations'], rollout['actions'], rollout['logprobs'],
            advantages, returns,
        )

        timestep_end = timestep_offset + (round_idx + 1) * rollout_steps
        row = {
            'env_name': env_name,
            'prompt_style': prompt_style,
            'phase': phase_name,
            'round': round_idx + 1,
            'global_round': global_round_offset + round_idx + 1,
            'timesteps_this_round': int(rollout_steps),
            'timestep_end': int(timestep_end),
            'avg_reward_model_score': float(np.mean(rollout['rewards'])) if len(rollout['rewards']) else 0.0,
            'avg_env_reward': float(np.mean(rollout['env_rewards'])) if len(rollout['env_rewards']) else 0.0,
            'segments_collected': len(segments),
            'new_comparisons': new_comparisons,
            'unclear_responses': unclear,
            'buffer_size': len(buffer),
        }
        if rm_final is not None:
            row['rm_final_loss'] = rm_final

        add_survival_metrics_to_row(
            row,
            env_name=env_name,
            env=env,
            policy=policy,
            survival_eval_episodes=survival_eval_episodes,
            survival_max_steps=survival_max_steps,
        )

        history.append(row)
        print(f'Prompt style: {prompt_style} | round {round_idx + 1}/{num_rounds} complete')

    return history


def evaluate_policy_with_env_reward(env, cfg, policy, value_net, rollout_steps=ROLLOUT_STEPS, survival_eval_episodes=10, survival_max_steps=None, training_env_name=None):
    rollout = collect_rollout(env, cfg, policy, value_net, reward_model=None, rollout_steps=rollout_steps)
    segs = rollout['segments']

    # Keep summary focused on non-survival aggregate eval metrics.
    metrics = {
        'env_avg_reward': float(np.mean(rollout['env_rewards'])) if len(rollout['env_rewards']) else 0.0,
        'env_total_reward': float(np.sum(rollout['env_rewards'])) if len(rollout['env_rewards']) else 0.0,
        'avg_time_upright': float(np.mean([s['time_upright'] for s in segs])) if segs else 0.0,
        'segments_collected': len(segs),
        'fell_segments': int(np.sum([1 for s in segs if s['fell']])) if segs else 0,
        'avg_forward_metric': float(np.mean([s['avg_forward_metric'] for s in segs])) if segs else 0.0,
        'forward_metric_name': segs[0]['forward_metric_name'] if segs else 'n/a',
    }

    return metrics


def compare_prompt_styles_on_env_reward_with_warmup(
    env_name, styles, llm_query_fn, warmup_rounds=5, rlhf_rounds=5,
    training_rollout_steps=ROLLOUT_STEPS, eval_rollout_steps=ROLLOUT_STEPS,
    seed=123, return_training_curve=False, return_json_payload=False,
    title=None, description=None,
    include_summary_in_payload=True,
    details_extra=None,
    survival_eval_episodes_per_round=10,
    survival_max_steps_per_round=None,
    include_ppo_only_baseline=True,
    ppo_only_label='ppo_only_policy',
):
    cfg = ENV_CONFIGS[env_name]
    results = []
    training_rows = []

    for i, style in enumerate(styles):
        run_seed = seed + i
        set_global_seed(run_seed)

        env, _ = make_env(env_name, seed=run_seed)
        policy = PolicyNetwork(cfg['obs_dim'], cfg['action_dim'])
        value_net = ValueNetwork(cfg['obs_dim'])
        reward_model = RewardModel(cfg['obs_dim'], cfg['action_dim'])
        buffer = ComparisonBuffer()

        print(f'\nEnv: {env_name} | Style: {style} | Phase 1: PPO warm-up ({warmup_rounds} rounds)')
        warmup_history = training_loop_no_llm(
            env=env,
            cfg=cfg,
            policy=policy,
            value_net=value_net,
            num_rounds=warmup_rounds,
            rollout_steps=training_rollout_steps,
            env_name=env_name,
            prompt_style=style,
            phase_name='warmup',
            timestep_offset=0,
            survival_eval_episodes=survival_eval_episodes_per_round,
            survival_max_steps=survival_max_steps_per_round,
        )

        print(f'Env: {env_name} | Style: {style} | Phase 2: RLHF ({rlhf_rounds} rounds)')
        rlhf_history = training_loop_with_prompt_style(
            env=env,
            cfg=cfg,
            env_name=env_name,
            policy=policy,
            value_net=value_net,
            reward_model=reward_model,
            buffer=buffer,
            prompt_style=style,
            llm_query_fn=llm_query_fn,
            num_rounds=rlhf_rounds,
            rollout_steps=training_rollout_steps,
            phase_name='rlhf',
            timestep_offset=warmup_rounds * training_rollout_steps,
            global_round_offset=warmup_rounds,
            survival_eval_episodes=survival_eval_episodes_per_round,
            survival_max_steps=survival_max_steps_per_round,
        )

        training_rows.extend(warmup_history)
        training_rows.extend(rlhf_history)

        eval_metrics = evaluate_policy_with_env_reward(
            env=env, cfg=cfg, policy=policy, value_net=value_net, rollout_steps=eval_rollout_steps,
            training_env_name=env_name
        )
        eval_metrics['env_name'] = env_name
        eval_metrics['prompt_style'] = style
        eval_metrics['warmup_rounds'] = warmup_rounds
        eval_metrics['rlhf_rounds'] = rlhf_rounds
        eval_metrics['buffer_size'] = len(buffer)
        results.append(eval_metrics)

        env.close()

    if include_ppo_only_baseline:
        ppo_seed = seed + 10000
        set_global_seed(ppo_seed)

        env, _ = make_env(env_name, seed=ppo_seed)
        policy = PolicyNetwork(cfg['obs_dim'], cfg['action_dim'])
        value_net = ValueNetwork(cfg['obs_dim'])

        total_rounds = warmup_rounds + rlhf_rounds
        print(f'\nEnv: {env_name} | PPO-only baseline ({total_rounds} rounds)')
        ppo_only_history = training_loop_no_llm(
            env=env,
            cfg=cfg,
            policy=policy,
            value_net=value_net,
            num_rounds=total_rounds,
            rollout_steps=training_rollout_steps,
            env_name=env_name,
            prompt_style=ppo_only_label,
            phase_name='ppo_only',
            timestep_offset=0,
            survival_eval_episodes=survival_eval_episodes_per_round,
            survival_max_steps=survival_max_steps_per_round,
        )
        training_rows.extend(ppo_only_history)

        ppo_eval_metrics = evaluate_policy_with_env_reward(
            env=env,
            cfg=cfg,
            policy=policy,
            value_net=value_net,
            rollout_steps=eval_rollout_steps,
            training_env_name=env_name,
        )
        ppo_eval_metrics['env_name'] = env_name
        ppo_eval_metrics['prompt_style'] = ppo_only_label
        ppo_eval_metrics['warmup_rounds'] = total_rounds
        ppo_eval_metrics['rlhf_rounds'] = 0
        ppo_eval_metrics['buffer_size'] = 0
        results.append(ppo_eval_metrics)

        env.close()

    summary_df = pd.DataFrame(results).sort_values('env_total_reward', ascending=False).reset_index(drop=True)
    curve_df = pd.DataFrame(training_rows)

    if not curve_df.empty:
        curve_df = curve_df.sort_values(['env_name', 'prompt_style', 'timestep_end']).reset_index(drop=True)

    if return_json_payload:
        payload_title = title if title is not None else f'{env_name.title()} Reward-vs-Timestep Curve'
        payload_description = description if description is not None else (
            f'Per-round training curve data for {env_name} using PPO warm-up followed by RLHF.'
        )

        payload = {
            'title': payload_title,
            'description': payload_description,
            'config': {
                'env_name': env_name,
                'warmup_rounds': warmup_rounds,
                'rlhf_rounds': rlhf_rounds,
                'training_rollout_steps': training_rollout_steps,
                'eval_rollout_steps': eval_rollout_steps,
                'seed': seed,
                'styles': list(styles),
                'survival_eval_episodes_per_round': survival_eval_episodes_per_round,
                'include_ppo_only_baseline': include_ppo_only_baseline,
                'ppo_only_label': ppo_only_label,
            },
            'details': {
                'num_styles': int(len(styles)),
                'total_training_rounds_per_style': int(warmup_rounds + rlhf_rounds),
                'total_training_timesteps_per_style': int((warmup_rounds + rlhf_rounds) * training_rollout_steps),
                'includes_warmup_phase': True,
                'includes_rlhf_phase': True,
                'includes_ppo_only_baseline': bool(include_ppo_only_baseline),
            },
            'data_points': curve_df.to_dict(orient='records'),
        }

        if details_extra is not None and isinstance(details_extra, dict):
            payload['details'].update(details_extra)

        if include_summary_in_payload:
            payload['summary'] = summary_df.to_dict(orient='records')

        return payload

    if return_training_curve:
        return summary_df, curve_df
    return summary_df

# %% [markdown]
# ## Run Setup

# %%
# LLM setup (same query pattern as RLLLMJOEL.ipynb)

from transformers import AutoTokenizer, AutoModelForCausalLM

try:
    from google.colab import userdata
    HF_TOKEN = userdata.get('HF_TOKEN')
except Exception:
    import os
    HF_TOKEN = os.getenv('HF_TOKEN')

MODEL_ID = "google/gemma-2-2b-it"

print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, token=HF_TOKEN)

print("Loading model ...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    token=HF_TOKEN,
    device_map="auto",
    dtype=torch.bfloat16,
 )

print(f"Model loaded on: {model.device}")
print(f"Model dtype:     {model.dtype}")

def query_llm(prompt, max_new_tokens=100):
    messages = [{"role": "user", "content": prompt}]

    input_ids = tokenizer.apply_chat_template(
        messages,
        return_tensors="pt",
        return_dict=True,
    ).to(model.device)

    input_length = input_ids["input_ids"].shape[1]

    with torch.no_grad():
        outputs = model.generate(
            **input_ids,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            temperature=1.0,
            pad_token_id=tokenizer.eos_token_id,
        )

    response = tokenizer.decode(
        outputs[0][input_length:],
        skip_special_tokens=True
    ).strip()

    return response
# Out:
# Loading tokenizer...
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Loading model ...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/288 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# Model loaded on: cuda:0
# Model dtype:     torch.bfloat16

# %%
# Hopper: Longer training run (~45-60 min target) with PPO warm-up + RLHF

import json

ENV_NAME = 'hopper'
styles_to_test = list(PROMPT_STYLES_BY_ENV['hopper'].keys())

# Requested settings
LONG_WARMUP_ROUNDS = 8
LONG_RLHF_ROUNDS = 8
LONG_TRAIN_ROLLOUT_STEPS = 3072
LONG_EVAL_ROLLOUT_STEPS = 3072

# Keep PPO epochs fixed as requested
PPO_EPOCHS = 4

# Optional increase for reward-model fitting during RLHF
RM_TRAIN_EPOCHS = 12

hopper_long_run_payload = compare_prompt_styles_on_env_reward_with_warmup(
    env_name=ENV_NAME,
    styles=styles_to_test,
    llm_query_fn=query_llm,
    warmup_rounds=LONG_WARMUP_ROUNDS,
    rlhf_rounds=LONG_RLHF_ROUNDS,
    training_rollout_steps=LONG_TRAIN_ROLLOUT_STEPS,
    eval_rollout_steps=LONG_EVAL_ROLLOUT_STEPS,
    seed=123,
    return_json_payload=True,
    title='Hopper Long-Run Reward-vs-Timestep Curve',
    description='Per-round training curve data for Hopper long run with PPO warm-up followed by RLHF.',
)

print('\nHopper long-run JSON payload:')
print(json.dumps(hopper_long_run_payload, indent=2))

# %%
# Pendulum: equivalent longer training run (same structure)

import json

ENV_NAME = 'pendulum'
styles_to_test = list(PROMPT_STYLES_BY_ENV['pendulum'].keys())

# Suggested settings for similar runtime target
LONG_WARMUP_ROUNDS = 8
LONG_RLHF_ROUNDS = 8
LONG_TRAIN_ROLLOUT_STEPS = 3072
LONG_EVAL_ROLLOUT_STEPS = 3072

PPO_EPOCHS = 4
RM_TRAIN_EPOCHS = 12

pendulum_long_run_payload = compare_prompt_styles_on_env_reward_with_warmup(
    env_name=ENV_NAME,
    styles=styles_to_test,
    llm_query_fn=query_llm,
    warmup_rounds=LONG_WARMUP_ROUNDS,
    rlhf_rounds=LONG_RLHF_ROUNDS,
    training_rollout_steps=LONG_TRAIN_ROLLOUT_STEPS,
    eval_rollout_steps=LONG_EVAL_ROLLOUT_STEPS,
    seed=123,
    return_json_payload=True,
    title='Pendulum Long-Run Reward-vs-Timestep Curve',
    description='Per-round training curve data for Pendulum long run with PPO warm-up followed by RLHF.',
)

print('\nPendulum long-run JSON payload:')
print(json.dumps(pendulum_long_run_payload, indent=2))

# %%
# Ant: equivalent longer training run (same structure)

import json

ENV_NAME = 'ant'
styles_to_test = list(PROMPT_STYLES_BY_ENV['ant'].keys())

LONG_WARMUP_ROUNDS = 8
LONG_RLHF_ROUNDS = 8
LONG_TRAIN_ROLLOUT_STEPS = 3072
LONG_EVAL_ROLLOUT_STEPS = 3072

PPO_EPOCHS = 4
RM_TRAIN_EPOCHS = 12

ant_long_run_payload = compare_prompt_styles_on_env_reward_with_warmup(
    env_name=ENV_NAME,
    styles=styles_to_test,
    llm_query_fn=query_llm,
    warmup_rounds=LONG_WARMUP_ROUNDS,
    rlhf_rounds=LONG_RLHF_ROUNDS,
    training_rollout_steps=LONG_TRAIN_ROLLOUT_STEPS,
    eval_rollout_steps=LONG_EVAL_ROLLOUT_STEPS,
    seed=123,
    return_json_payload=True,
    title='Ant Long-Run Reward-vs-Timestep Curve',
    description='Per-round training curve data for Ant long run with PPO warm-up followed by RLHF.',
)

print('\nAnt long-run JSON payload:')
print(json.dumps(ant_long_run_payload, indent=2))

# %%
# Quick-run variant for debugging (both environments, shorter runtime)
import json

QUICK_WARMUP_ROUNDS = 2
QUICK_RLHF_ROUNDS = 2
QUICK_TRAIN_ROLLOUT_STEPS = 1024
QUICK_EVAL_ROLLOUT_STEPS = 1024

quick_hopper_df, quick_hopper_curve_df = compare_prompt_styles_on_env_reward_with_warmup(
    env_name='hopper',
    styles=list(PROMPT_STYLES_BY_ENV['hopper'].keys()),
    llm_query_fn=query_llm,
    warmup_rounds=QUICK_WARMUP_ROUNDS,
    rlhf_rounds=QUICK_RLHF_ROUNDS,
    training_rollout_steps=QUICK_TRAIN_ROLLOUT_STEPS,
    eval_rollout_steps=QUICK_EVAL_ROLLOUT_STEPS,
    seed=202,
    return_training_curve=True,
 )

quick_pendulum_df, quick_pendulum_curve_df = compare_prompt_styles_on_env_reward_with_warmup(
    env_name='pendulum',
    styles=list(PROMPT_STYLES_BY_ENV['pendulum'].keys()),
    llm_query_fn=query_llm,
    warmup_rounds=QUICK_WARMUP_ROUNDS,
    rlhf_rounds=QUICK_RLHF_ROUNDS,
    training_rollout_steps=QUICK_TRAIN_ROLLOUT_STEPS,
    eval_rollout_steps=QUICK_EVAL_ROLLOUT_STEPS,
    seed=303,
    return_training_curve=True,
 )

# quick_ant_df, quick_ant_curve_df = compare_prompt_styles_on_env_reward_with_warmup(
#     env_name='ant',
#     styles=list(PROMPT_STYLES_BY_ENV['ant'].keys()),
#     llm_query_fn=query_llm,
#     warmup_rounds=QUICK_WARMUP_ROUNDS,
#     rlhf_rounds=QUICK_RLHF_ROUNDS,
#     training_rollout_steps=QUICK_TRAIN_ROLLOUT_STEPS,
#     eval_rollout_steps=QUICK_EVAL_ROLLOUT_STEPS,
#     seed=404,
#     return_training_curve=True,
# )

# print('Quick Ant summary results:')
# display(quick_ant_df)

# print('Quick Ant training curve:')
# display(quick_ant_curve_df[['env_name', 'prompt_style', 'phase', 'round', 'global_round', 'timestep_end', 'avg_env_reward', 'avg_reward_model_score']])

print('Quick Hopper summary results:')
display(quick_hopper_df)

print('Quick Hopper training curve (reward vs timestep data):')
display(quick_hopper_curve_df[['env_name', 'prompt_style', 'phase', 'round', 'global_round', 'timestep_end', 'avg_env_reward', 'avg_reward_model_score']])

print('Quick Pendulum summary results:')
display(quick_pendulum_df)

print('Quick Pendulum training curve (reward vs timestep data):')
display(quick_pendulum_curve_df[['env_name', 'prompt_style', 'phase', 'round', 'global_round', 'timestep_end', 'avg_env_reward', 'avg_reward_model_score']])

quick_hopper_payload = compare_prompt_styles_on_env_reward_with_warmup(
    env_name='hopper',
    styles=list(PROMPT_STYLES_BY_ENV['hopper'].keys()),
    llm_query_fn=query_llm,
    warmup_rounds=QUICK_WARMUP_ROUNDS,
    rlhf_rounds=QUICK_RLHF_ROUNDS,
    training_rollout_steps=QUICK_TRAIN_ROLLOUT_STEPS,
    eval_rollout_steps=QUICK_EVAL_ROLLOUT_STEPS,
    seed=202,
    return_json_payload=True,
    title='Quick Hopper Reward-vs-Timestep Curve',
    description='Per-round training curve data for Hopper quick run with PPO warm-up followed by RLHF.',
)

quick_pendulum_payload = compare_prompt_styles_on_env_reward_with_warmup(
    env_name='pendulum',
    styles=list(PROMPT_STYLES_BY_ENV['pendulum'].keys()),
    llm_query_fn=query_llm,
    warmup_rounds=QUICK_WARMUP_ROUNDS,
    rlhf_rounds=QUICK_RLHF_ROUNDS,
    training_rollout_steps=QUICK_TRAIN_ROLLOUT_STEPS,
    eval_rollout_steps=QUICK_EVAL_ROLLOUT_STEPS,
    seed=303,
    return_json_payload=True,
    title='Quick Pendulum Reward-vs-Timestep Curve',
    description='Per-round training curve data for Pendulum quick run with PPO warm-up followed by RLHF.',
)

# quick_ant_payload = compare_prompt_styles_on_env_reward_with_warmup(
#     env_name='ant',
#     styles=list(PROMPT_STYLES_BY_ENV['ant'].keys()),
#     llm_query_fn=query_llm,
#     warmup_rounds=QUICK_WARMUP_ROUNDS,
#     rlhf_rounds=QUICK_RLHF_ROUNDS,
#     training_rollout_steps=QUICK_TRAIN_ROLLOUT_STEPS,
#     eval_rollout_steps=QUICK_EVAL_ROLLOUT_STEPS,
#     seed=404,
#     return_json_payload=True,
#     title='Quick Ant Reward-vs-Timestep Curve',
#     description='Per-round training curve data for Ant quick run with PPO warm-up followed by RLHF.',
# )

# print('\nQuick Ant JSON payload:')
# print(json.dumps(quick_ant_payload, indent=2))

print('\nQuick Hopper JSON payload:')
print(json.dumps(quick_hopper_payload, indent=2))

print('\nQuick Pendulum JSON payload:')
print(json.dumps(quick_pendulum_payload, indent=2))
# Out:
# Env: hopper | Style: balanced_goal_first | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: hopper | Style: balanced_goal_first | Phase 2: RLHF (2 rounds)
# Prompt style: balanced_goal_first | round 1/2 complete
# Prompt style: balanced_goal_first | round 2/2 complete
#
# Env: hopper | Style: checklist_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: hopper | Style: checklist_style | Phase 2: RLHF (2 rounds)
# Prompt style: checklist_style | round 1/2 complete
# Prompt style: checklist_style | round 2/2 complete
#
# Env: hopper | Style: minimal_stats_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: hopper | Style: minimal_stats_style | Phase 2: RLHF (2 rounds)
# Prompt style: minimal_stats_style | round 1/2 complete
# Prompt style: minimal_stats_style | round 2/2 complete
#
# Env: hopper | PPO-only baseline (4 rounds)
# Baseline round 1/4 complete
# Baseline round 2/4 complete
# Baseline round 3/4 complete
# Baseline round 4/4 complete
#
# Env: pendulum | Style: balanced_goal_first | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: pendulum | Style: balanced_goal_first | Phase 2: RLHF (2 rounds)
# Prompt style: balanced_goal_first | round 1/2 complete
# Prompt style: balanced_goal_first | round 2/2 complete
#
# Env: pendulum | Style: checklist_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: pendulum | Style: checklist_style | Phase 2: RLHF (2 rounds)
# Prompt style: checklist_style | round 1/2 complete
# Prompt style: checklist_style | round 2/2 complete
#
# Env: pendulum | Style: minimal_stats_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: pendulum | Style: minimal_stats_style | Phase 2: RLHF (2 rounds)
# Prompt style: minimal_stats_style | round 1/2 complete
# Prompt style: minimal_stats_style | round 2/2 complete
#
# Env: pendulum | PPO-only baseline (4 rounds)
# Baseline round 1/4 complete
# Baseline round 2/4 complete
# Baseline round 3/4 complete
# Baseline round 4/4 complete
# Quick Hopper summary results:
#    env_avg_reward  env_total_reward  avg_time_upright  segments_collected  \
# 0        0.867738        888.563808              50.0                  20
# 1        0.853835        874.327444              50.0                  20
# 2        0.834580        854.610257              50.0                  20
# 3        0.804343        823.646782              50.0                  20
#
#    fell_segments  avg_forward_metric   forward_metric_name env_name  \
# 0              2           -0.067328  avg_forward_velocity   hopper
# 1              2           -0.093750  avg_forward_velocity   hopper
# 2              2           -0.093131  avg_forward_velocity   hopper
# 3              1           -0.154636  avg_forward_velocity   hopper
#
#           prompt_style  warmup_rounds  rlhf_rounds  buffer_size
# 0      ppo_only_policy              4            0            0
# 1  minimal_stats_style              2            2           40
# 2  balanced_goal_first              2            2           40
# 3      checklist_style              2            2           40
# Quick Hopper training curve (reward vs timestep data):
#    env_name         prompt_style     phase  round  global_round  timestep_end  \
# 0    hopper  balanced_goal_first    warmup      1             1          1024
# 1    hopper  balanced_goal_first    warmup      2             2          2048
# 2    hopper  balanced_goal_first      rlhf      1             3          3072
# 3    hopper  balanced_goal_first      rlhf      2             4          4096
# 4    hopper      checklist_style    warmup      1             1          1024
# 5    hopper      checklist_style    warmup      2             2          2048
# 6    hopper      checklist_style      rlhf      1             3          3072
# 7    hopper      checklist_style      rlhf      2             4          4096
# 8    hopper  minimal_stats_style    warmup      1             1          1024
# 9    hopper  minimal_stats_style    warmup      2             2          2048
# 10   hopper  minimal_stats_style      rlhf      1             3          3072
# 11   hopper  minimal_stats_style      rlhf      2             4          4096
# 12   hopper      ppo_only_policy  ppo_only      1             1          1024
# 13   hopper      ppo_only_policy  ppo_only      2             2          2048
# 14   hopper      ppo_only_policy  ppo_only      3             3          3072
# 15   hopper      ppo_only_policy  ppo_only      4             4          4096
#
#     avg_env_reward  avg_reward_model_score
# 0         0.729810                0.729810
# 1         0.657943                0.657943
# 2         0.949755                0.104565
# 3         0.724995               -0.005083
# 4         0.835425                0.835425
# 5         0.779278                0.779278
# 6         0.799252               -0.011144
# 7         0.886384               -0.231360
# 8         0.798798                0.798798
# 9         0.886579                0.886579
# 10        0.678080                0.105559
# 11        0.775339                0.324165
# 12        0.862188                0.862188
# 13        0.764839                0.764839
# 14        0.729256                0.729256
# 15        0.690724                0.690724
# Quick Pendulum summary results:
#    env_avg_reward  env_total_reward  avg_time_upright  segments_collected  \
# 0       -5.857006      -5997.573815              3.10                  20
# 1       -6.115477      -6262.248426              5.00                  20
# 2       -6.367319      -6520.135019              3.95                  20
# 3       -6.615555      -6774.328618              3.60                  20
#
#    fell_segments  avg_forward_metric forward_metric_name  env_name  \
# 0              0           -1.912770  negative_abs_angle  pendulum
# 1              0           -1.990112  negative_abs_angle  pendulum
# 2              0           -2.133495  negative_abs_angle  pendulum
# 3              0           -2.212959  negative_abs_angle  pendulum
#
#           prompt_style  warmup_rounds  rlhf_rounds  buffer_size
# 0  minimal_stats_style              2            2           40
# 1      checklist_style              2            2           40
# 2      ppo_only_policy              4            0            0
# 3  balanced_goal_first              2            2           40
# Quick Pendulum training curve (reward vs timestep data):
#     env_name         prompt_style     phase  round  global_round  \
# 0   pendulum  balanced_goal_first    warmup      1             1
# 1   pendulum  balanced_goal_first    warmup      2             2
# 2   pendulum  balanced_goal_first      rlhf      1             3
# 3   pendulum  balanced_goal_first      rlhf      2             4
# 4   pendulum      checklist_style    warmup      1             1
# 5   pendulum      checklist_style    warmup      2             2
# 6   pendulum      checklist_style      rlhf      1             3
# 7   pendulum      checklist_style      rlhf      2             4
# 8   pendulum  minimal_stats_style    warmup      1             1
# 9   pendulum  minimal_stats_style    warmup      2             2
# 10  pendulum  minimal_stats_style      rlhf      1             3
# 11  pendulum  minimal_stats_style      rlhf      2             4
# 12  pendulum      ppo_only_policy  ppo_only      1             1
# 13  pendulum      ppo_only_policy  ppo_only      2             2
# 14  pendulum      ppo_only_policy  ppo_only      3             3
# 15  pendulum      ppo_only_policy  ppo_only      4             4
#
#     timestep_end  avg_env_reward  avg_reward_model_score
# 0           1024       -5.715103               -5.715103
# 1           2048       -6.942552               -6.942552
# 2           3072       -6.556248               -0.011710
# 3           4096       -6.992012               -0.194348
# 4           1024       -5.713288               -5.713288
# 5           2048       -6.006046               -6.006046
# 6           3072       -6.256798                0.075236
# 7           4096       -5.112700                0.091364
# 8           1024       -6.716953               -6.716953
# 9           2048       -6.839330               -6.839330
# 10          3072       -6.307924               -0.042944
# 11          4096       -5.189775                0.227397
# 12          1024       -5.907239               -5.907239
# 13          2048       -7.692364               -7.692364
# 14          3072       -7.055171               -7.055171
# 15          4096       -7.156770               -7.156770
# Env: hopper | Style: balanced_goal_first | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: hopper | Style: balanced_goal_first | Phase 2: RLHF (2 rounds)
# Prompt style: balanced_goal_first | round 1/2 complete
# Prompt style: balanced_goal_first | round 2/2 complete
#
# Env: hopper | Style: checklist_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: hopper | Style: checklist_style | Phase 2: RLHF (2 rounds)
# Prompt style: checklist_style | round 1/2 complete
# Prompt style: checklist_style | round 2/2 complete
#
# Env: hopper | Style: minimal_stats_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: hopper | Style: minimal_stats_style | Phase 2: RLHF (2 rounds)
# Prompt style: minimal_stats_style | round 1/2 complete
# Prompt style: minimal_stats_style | round 2/2 complete
#
# Env: hopper | PPO-only baseline (4 rounds)
# Baseline round 1/4 complete
# Baseline round 2/4 complete
# Baseline round 3/4 complete
# Baseline round 4/4 complete
#
# Env: pendulum | Style: balanced_goal_first | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: pendulum | Style: balanced_goal_first | Phase 2: RLHF (2 rounds)
# Prompt style: balanced_goal_first | round 1/2 complete
# Prompt style: balanced_goal_first | round 2/2 complete
#
# Env: pendulum | Style: checklist_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: pendulum | Style: checklist_style | Phase 2: RLHF (2 rounds)
# Prompt style: checklist_style | round 1/2 complete
# Prompt style: checklist_style | round 2/2 complete
#
# Env: pendulum | Style: minimal_stats_style | Phase 1: PPO warm-up (2 rounds)
# Baseline round 1/2 complete
# Baseline round 2/2 complete
# Env: pendulum | Style: minimal_stats_style | Phase 2: RLHF (2 rounds)
# Prompt style: minimal_stats_style | round 1/2 complete
# Prompt style: minimal_stats_style | round 2/2 complete
#
# Env: pendulum | PPO-only baseline (4 rounds)
# Baseline round 1/4 complete
# Baseline round 2/4 complete
# Baseline round 3/4 complete
# Baseline round 4/4 complete
#
# Quick Hopper JSON payload:
# {
#   "title": "Quick Hopper Reward-vs-Timestep Curve",
#   "description": "Per-round training curve data for Hopper quick run with PPO warm-up followed by RLHF.",
#   "config": {
#     "env_name": "hopper",
#     "warmup_rounds": 2,
#     "rlhf_rounds": 2,
#     "training_rollout_steps": 1024,
#     "eval_rollout_steps": 1024,
#     "seed": 202,
#     "styles": [
#       "balanced_goal_first",
#       "checklist_style",
#       "minimal_stats_style"
#     ],
#     "survival_eval_episodes_per_round": 10,
#     "include_ppo_only_baseline": true,
#     "ppo_only_label": "ppo_only_policy"
#   },
#   "details": {
#     "num_styles": 3,
#     "total_training_rounds_per_style": 4,
#     "total_training_timesteps_per_style": 4096,
#     "includes_warmup_phase": true,
#     "includes_rlhf_phase": true,
#     "includes_ppo_only_baseline": true
#   },
#   "data_points": [
#     {
#       "env_name": "hopper",
#       "prompt_style": "balanced_goal_first",
#       "phase": "warmup",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": 0.7298098298296929,
#       "avg_reward_model_score": 0.7298098298296929,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 21.299999237060547,
#       "episode_length_median": 19.0,
#       "episode_length_max": 36,
#       "episode_length_min": 8,
#       "episode_length_std": 8.343260765075684,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "balanced_goal_first",
#       "phase": "warmup",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": 0.6579431602715538,
#       "avg_reward_model_score": 0.6579431602715538,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 18.299999237060547,
#       "episode_length_median": 15.5,
#       "episode_length_max": 46,
#       "episode_length_min": 7,
#       "episode_length_std": 10.50761604309082,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "balanced_goal_first",
#       "phase": "rlhf",
#       "round": 1,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": 0.9497545183518159,
#       "avg_reward_model_score": 0.10456492140656337,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 20,
#       "rm_final_loss": 0.30478197185556194,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 17.799999237060547,
#       "episode_length_median": 13.0,
#       "episode_length_max": 52,
#       "episode_length_min": 8,
#       "episode_length_std": 12.820296287536621,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "balanced_goal_first",
#       "phase": "rlhf",
#       "round": 2,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": 0.72499475767021,
#       "avg_reward_model_score": -0.0050832028973673005,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 40,
#       "rm_final_loss": 0.18825561691813802,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 20.299999237060547,
#       "episode_length_median": 21.0,
#       "episode_length_max": 31,
#       "episode_length_min": 10,
#       "episode_length_std": 6.664083003997803,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "checklist_style",
#       "phase": "warmup",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": 0.8354245937234953,
#       "avg_reward_model_score": 0.8354245937234953,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 20.399999618530273,
#       "episode_length_median": 20.5,
#       "episode_length_max": 30,
#       "episode_length_min": 12,
#       "episode_length_std": 5.7827324867248535,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "checklist_style",
#       "phase": "warmup",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": 0.7792775611628732,
#       "avg_reward_model_score": 0.7792775611628732,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 18.0,
#       "episode_length_median": 11.5,
#       "episode_length_max": 41,
#       "episode_length_min": 9,
#       "episode_length_std": 11.269427299499512,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "checklist_style",
#       "phase": "rlhf",
#       "round": 1,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": 0.7992520974097039,
#       "avg_reward_model_score": -0.011143970361445099,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 20,
#       "rm_final_loss": 0.65541704587813,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 23.5,
#       "episode_length_median": 19.0,
#       "episode_length_max": 60,
#       "episode_length_min": 12,
#       "episode_length_std": 14.016061782836914,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "checklist_style",
#       "phase": "rlhf",
#       "round": 2,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": 0.8863843228964626,
#       "avg_reward_model_score": -0.2313604892933654,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 40,
#       "rm_final_loss": 0.603367267805444,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 25.299999237060547,
#       "episode_length_median": 19.5,
#       "episode_length_max": 57,
#       "episode_length_min": 10,
#       "episode_length_std": 15.388632774353027,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "minimal_stats_style",
#       "phase": "warmup",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": 0.7987976554092808,
#       "avg_reward_model_score": 0.7987976554092808,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 16.0,
#       "episode_length_median": 14.5,
#       "episode_length_max": 35,
#       "episode_length_min": 7,
#       "episode_length_std": 7.5762786865234375,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "minimal_stats_style",
#       "phase": "warmup",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": 0.8865792814607962,
#       "avg_reward_model_score": 0.8865792814607962,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 16.200000762939453,
#       "episode_length_median": 15.0,
#       "episode_length_max": 32,
#       "episode_length_min": 10,
#       "episode_length_std": 6.368673324584961,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "minimal_stats_style",
#       "phase": "rlhf",
#       "round": 1,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": 0.6780800844014143,
#       "avg_reward_model_score": 0.1055591630743038,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 20,
#       "rm_final_loss": 1.4567905016522396,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 21.799999237060547,
#       "episode_length_median": 19.0,
#       "episode_length_max": 60,
#       "episode_length_min": 10,
#       "episode_length_std": 13.31014633178711,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "minimal_stats_style",
#       "phase": "rlhf",
#       "round": 2,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": 0.775338542502104,
#       "avg_reward_model_score": 0.3241654046551048,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 40,
#       "rm_final_loss": 0.7769180731147116,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 21.200000762939453,
#       "episode_length_median": 18.5,
#       "episode_length_max": 57,
#       "episode_length_min": 11,
#       "episode_length_std": 12.990765571594238,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": 0.8621882255980712,
#       "avg_reward_model_score": 0.8621882255980712,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 21.700000762939453,
#       "episode_length_median": 17.0,
#       "episode_length_max": 59,
#       "episode_length_min": 9,
#       "episode_length_std": 13.572399139404297,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": 0.7648386361760029,
#       "avg_reward_model_score": 0.7648386361760029,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 20.100000381469727,
#       "episode_length_median": 15.5,
#       "episode_length_max": 63,
#       "episode_length_min": 8,
#       "episode_length_std": 15.042939186096191,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 3,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": 0.7292561940566464,
#       "avg_reward_model_score": 0.7292561940566464,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 23.0,
#       "episode_length_median": 20.0,
#       "episode_length_max": 30,
#       "episode_length_min": 17,
#       "episode_length_std": 4.795831680297852,
#       "survival_eval_episodes": 10
#     },
#     {
#       "env_name": "hopper",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 4,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": 0.690723857499971,
#       "avg_reward_model_score": 0.690723857499971,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": true,
#       "episode_length_mean": 16.700000762939453,
#       "episode_length_median": 15.0,
#       "episode_length_max": 32,
#       "episode_length_min": 8,
#       "episode_length_std": 8.43860149383545,
#       "survival_eval_episodes": 10
#     }
#   ],
#   "summary": [
#     {
#       "env_avg_reward": 0.8677380934160637,
#       "env_total_reward": 888.5638076580492,
#       "avg_time_upright": 50.0,
#       "segments_collected": 20,
#       "fell_segments": 2,
#       "avg_forward_metric": -0.06732790275624197,
#       "forward_metric_name": "avg_forward_velocity",
#       "env_name": "hopper",
#       "prompt_style": "ppo_only_policy",
#       "warmup_rounds": 4,
#       "rlhf_rounds": 0,
#       "buffer_size": 0
#     },
#     {
#       "env_avg_reward": 0.853835394882402,
#       "env_total_reward": 874.3274443595797,
#       "avg_time_upright": 50.0,
#       "segments_collected": 20,
#       "fell_segments": 2,
#       "avg_forward_metric": -0.0937498016439506,
#       "forward_metric_name": "avg_forward_velocity",
#       "env_name": "hopper",
#       "prompt_style": "minimal_stats_style",
#       "warmup_rounds": 2,
#       "rlhf_rounds": 2,
#       "buffer_size": 40
#     },
#     {
#       "env_avg_reward": 0.8345803289660221,
#       "env_total_reward": 854.6102568612066,
#       "avg_time_upright": 50.0,
#       "segments_collected": 20,
#       "fell_segments": 2,
#       "avg_forward_metric": -0.09313054596941553,
#       "forward_metric_name": "avg_forward_velocity",
#       "env_name": "hopper",
#       "prompt_style": "balanced_goal_first",
#       "warmup_rounds": 2,
#       "rlhf_rounds": 2,
#       "buffer_size": 40
#     },
#     {
#       "env_avg_reward": 0.8043425608458841,
#       "env_total_reward": 823.6467823061853,
#       "avg_time_upright": 50.0,
#       "segments_collected": 20,
#       "fell_segments": 1,
#       "avg_forward_metric": -0.15463552895430782,
#       "forward_metric_name": "avg_forward_velocity",
#       "env_name": "hopper",
#       "prompt_style": "checklist_style",
#       "warmup_rounds": 2,
#       "rlhf_rounds": 2,
#       "buffer_size": 40
#     }
#   ]
# }
#
# Quick Pendulum JSON payload:
# {
#   "title": "Quick Pendulum Reward-vs-Timestep Curve",
#   "description": "Per-round training curve data for Pendulum quick run with PPO warm-up followed by RLHF.",
#   "config": {
#     "env_name": "pendulum",
#     "warmup_rounds": 2,
#     "rlhf_rounds": 2,
#     "training_rollout_steps": 1024,
#     "eval_rollout_steps": 1024,
#     "seed": 303,
#     "styles": [
#       "balanced_goal_first",
#       "checklist_style",
#       "minimal_stats_style"
#     ],
#     "survival_eval_episodes_per_round": 10,
#     "include_ppo_only_baseline": true,
#     "ppo_only_label": "ppo_only_policy"
#   },
#   "details": {
#     "num_styles": 3,
#     "total_training_rounds_per_style": 4,
#     "total_training_timesteps_per_style": 4096,
#     "includes_warmup_phase": true,
#     "includes_rlhf_phase": true,
#     "includes_ppo_only_baseline": true
#   },
#   "data_points": [
#     {
#       "env_name": "pendulum",
#       "prompt_style": "balanced_goal_first",
#       "phase": "warmup",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": -5.715103259583789,
#       "avg_reward_model_score": -5.715103259583789,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "balanced_goal_first",
#       "phase": "warmup",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": -6.942551545617132,
#       "avg_reward_model_score": -6.942551545617132,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "balanced_goal_first",
#       "phase": "rlhf",
#       "round": 1,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": -6.556248209045045,
#       "avg_reward_model_score": -0.011710026543369167,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 20,
#       "rm_final_loss": 2.0839943289306406,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "balanced_goal_first",
#       "phase": "rlhf",
#       "round": 2,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": -6.9920117813203255,
#       "avg_reward_model_score": -0.19434845650175703,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 40,
#       "rm_final_loss": 1.4981689246895449,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "checklist_style",
#       "phase": "warmup",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": -5.713288015513433,
#       "avg_reward_model_score": -5.713288015513433,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "checklist_style",
#       "phase": "warmup",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": -6.006046257345325,
#       "avg_reward_model_score": -6.006046257345325,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "checklist_style",
#       "phase": "rlhf",
#       "round": 1,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": -6.256797834778789,
#       "avg_reward_model_score": 0.07523558136836073,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 20,
#       "rm_final_loss": 0.94671736637946,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "checklist_style",
#       "phase": "rlhf",
#       "round": 2,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": -5.112699721238473,
#       "avg_reward_model_score": 0.0913644253541861,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 40,
#       "rm_final_loss": 2.3497670893171483,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "minimal_stats_style",
#       "phase": "warmup",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": -6.716952520520001,
#       "avg_reward_model_score": -6.716952520520001,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "minimal_stats_style",
#       "phase": "warmup",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": -6.83933045170841,
#       "avg_reward_model_score": -6.83933045170841,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "minimal_stats_style",
#       "phase": "rlhf",
#       "round": 1,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": -6.307924428663247,
#       "avg_reward_model_score": -0.04294418955032597,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 20,
#       "rm_final_loss": 1.5949058302212507,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "minimal_stats_style",
#       "phase": "rlhf",
#       "round": 2,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": -5.189775307965974,
#       "avg_reward_model_score": 0.22739709959569154,
#       "segments_collected": 20,
#       "new_comparisons": 20,
#       "unclear_responses": 0,
#       "buffer_size": 40,
#       "rm_final_loss": 1.926191697110884,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 1,
#       "global_round": 1,
#       "timesteps_this_round": 1024,
#       "timestep_end": 1024,
#       "avg_env_reward": -5.907239019210658,
#       "avg_reward_model_score": -5.907239019210658,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 2,
#       "global_round": 2,
#       "timesteps_this_round": 1024,
#       "timestep_end": 2048,
#       "avg_env_reward": -7.692364004487491,
#       "avg_reward_model_score": -7.692364004487491,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 3,
#       "global_round": 3,
#       "timesteps_this_round": 1024,
#       "timestep_end": 3072,
#       "avg_env_reward": -7.055171344455889,
#       "avg_reward_model_score": -7.055171344455889,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     },
#     {
#       "env_name": "pendulum",
#       "prompt_style": "ppo_only_policy",
#       "phase": "ppo_only",
#       "round": 4,
#       "global_round": 4,
#       "timesteps_this_round": 1024,
#       "timestep_end": 4096,
#       "avg_env_reward": -7.156770247746966,
#       "avg_reward_model_score": -7.156770247746966,
#       "segments_collected": 20,
#       "new_comparisons": 0,
#       "unclear_responses": 0,
#       "buffer_size": 0,
#       "rm_final_loss": NaN,
#       "survival_metrics_collected": false,
#       "episode_length_mean": null,
#       "episode_length_median": null,
#       "episode_length_max": null,
#       "episode_length_min": null,
#       "episode_length_std": null,
#       "survival_eval_episodes": 0
#     }
#   ],
#   "summary": [
#     {
#       "env_avg_reward": -5.857005678549321,
#       "env_total_reward": -5997.573814834504,
#       "avg_time_upright": 3.1,
#       "segments_collected": 20,
#       "fell_segments": 0,
#       "avg_forward_metric": -1.9127698063850402,
#       "forward_metric_name": "negative_abs_angle",
#       "env_name": "pendulum",
#       "prompt_style": "minimal_stats_style",
#       "warmup_rounds": 2,
#       "rlhf_rounds": 2,
#       "buffer_size": 40
#     },
#     {
#       "env_avg_reward": -6.11547697891452,
#       "env_total_reward": -6262.248426408469,
#       "avg_time_upright": 5.0,
#       "segments_collected": 20,
#       "fell_segments": 0,
#       "avg_forward_metric": -1.9901116728782653,
#       "forward_metric_name": "negative_abs_angle",
#       "env_name": "pendulum",
#       "prompt_style": "checklist_style",
#       "warmup_rounds": 2,
#       "rlhf_rounds": 2,
#       "buffer_size": 40
#     },
#     {
#       "env_avg_reward": -6.367319354401185,
#       "env_total_reward": -6520.1350189068135,
#       "avg_time_upright": 3.95,
#       "segments_collected": 20,
#       "fell_segments": 0,
#       "avg_forward_metric": -2.133495235443115,
#       "forward_metric_name": "negative_abs_angle",
#       "env_name": "pendulum",
#       "prompt_style": "ppo_only_policy",
#       "warmup_rounds": 4,
#       "rlhf_rounds": 0,
#       "buffer_size": 0
#     },
#     {
#       "env_avg_reward": -6.615555290938066,
#       "env_total_reward": -6774.32861792058,
#       "avg_time_upright": 3.6,
#       "segments_collected": 20,
#       "fell_segments": 0,
#       "avg_forward_metric": -2.2129591733217238,
#       "forward_metric_name": "negative_abs_angle",
#       "env_name": "pendulum",
#       "prompt_style": "balanced_goal_first",
#       "warmup_rounds": 2,
#       "rlhf_rounds": 2,
#       "buffer_size": 40
#     }
#   ]
# }

# %% [markdown]
# ## Video generation and LLM Queries

# %%
# !pip install qwen-vl-utils --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 21.7 MB/s eta 0:00:00

# %%
import base64
import io
from PIL import Image, ImageDraw, ImageFont
import numpy as np

def replay_segment_to_frames(env_id: str, action_seq: np.ndarray, max_frames: int = None) -> list:
  render_env = gym.make(env_id, render_mode='rgb_array')
  render_env.reset(seed=0)

  frames = []
  steps_to_render = (
      np.linspace(0, len(action_seq) - 1, max_frames, dtype=int)
      if max_frames is not None
      else range(len(action_seq))
  )
  steps_to_render_set = set(steps_to_render)

  for t, action in enumerate(action_seq):
    frame = render_env.render()
    if t in steps_to_render_set:
      frames.append(frame.copy())
    _, _, terminated, truncated, _ = render_env.step(action)
    if terminated or truncated:
      frames.append(render_env.render().copy())
      break
  render_env.close()
  return frames

def select_keyframes(frames: list, n_keyframes: int = 6) -> list:
  if len(frames) <= n_keyframes:
    return frames
  indicies = np.linspace(0, len(frames)-1, n_keyframes, dtype=int)
  return [frames[i] for i in indicies]

def build_comparison_grid(frames_a: list, frames_b: list,
                          label_a: str = "Segment A",
                          label_b: str = "Segment B",
                          frame_size: tuple = (120, 120),
                          add_labels: bool = True,
                          velocities_a: list = None,   # ← added
                          velocities_b: list = None,   # ← added
                          ) -> Image.Image:
    fw, fh      = frame_size
    label_width = 90 if add_labels else 0
    n_cols      = max(len(frames_a), len(frames_b))

    total_width  = n_cols * fw + label_width
    total_height = 2 * fh

    grid = Image.new("RGB", (total_width, total_height), color=(30, 30, 30))
    draw = ImageDraw.Draw(grid)

    if add_labels:
        draw.rectangle([0, 0, label_width - 1, fh - 1],      fill=(50, 50, 50))
        draw.rectangle([0, fh, label_width - 1, 2 * fh - 1], fill=(50, 50, 50))
        draw.text((5, fh // 2 - 8),      label_a, fill=(255, 255, 255))
        draw.text((5, fh + fh // 2 - 8), label_b, fill=(255, 255, 255))

    # pair each row with its velocity list (None if not provided)
    rows = [
        (frames_a, velocities_a),
        (frames_b, velocities_b),
    ]

    for row_idx, (frames, velocities) in enumerate(rows):
        y_offset = row_idx * fh
        for col_idx, frame in enumerate(frames):
            x_offset = label_width + col_idx * fw
            pil_frame = Image.fromarray(frame).resize(
                frame_size, Image.LANCZOS
            )
            grid.paste(pil_frame, (x_offset, y_offset))

            # overlay velocity text if provided for this row
            if velocities is not None and col_idx < len(velocities):
                vel   = velocities[col_idx]
                color = (0, 255, 0) if vel > 0 else (255, 80, 80)
                draw.text(
                    (x_offset + 4, y_offset + fh - 16),
                    f"v={vel:+.2f}",
                    fill=color
                )

    return grid



def image_to_base64(image: Image.Image, fmt: str = "JPEG",
                    quality: int = 85) -> str:
  buffer = io.BytesIO()
  if fmt == "JPEG":
    image.save(buffer, format="JPEG", quality=quality)
  else:
    image.save(buffer, format="PNG")
  return base64.b64encode(buffer.getvalue()).decode("utf-8")



def build_segment_grid_b64(seg_a: dict, seg_b: dict,
                           env_id: str,
                           n_keyframes: int = 6,
                           frame_size: tuple = (120, 120)) -> str:
  frames_a = replay_segment_to_frames(
      env_id, seg_a["actions"], max_frames=n_keyframes
  )
  frames_b = replay_segment_to_frames(
      env_id, seg_b["actions"], max_frames=n_keyframes
  )

  keys_a = select_keyframes(frames_a, n_keyframes)
  keys_b = select_keyframes(frames_b, n_keyframes)

  grid = build_comparison_grid(
      keys_a, keys_b, frame_size=frame_size
  )
  return image_to_base64(grid)

# %%
def extract_keyframe_velocities(seg: dict, cfg: dict,
                                 n_keyframes: int) -> list:
    """
    Extract forward velocity values at the same keyframe indices
    used for the image grid, so the velocity overlay aligns with
    the correct frames.
    """
    import numpy as np   # ← moved here, outside the if/elif blocks

    obs_arr   = seg["observations"]
    fwd_idx   = cfg.get("forward_index",    cfg.get("x_velocity_index", None))
    cos_idx   = cfg.get("cos_index", None)

    if fwd_idx is not None:
        # Hopper, Ant — direct velocity index
        all_vels = obs_arr[:, fwd_idx].tolist()
    elif cos_idx is not None:
        # Pendulum — use angular velocity as proxy
        theta_dot_idx = cfg.get("theta_dot_index", 2)
        all_vels      = obs_arr[:, theta_dot_idx].tolist()
    else:
        return None

    # select the same indices as select_keyframes would
    T = len(all_vels)
    if T <= n_keyframes:
        return all_vels
    indices = np.linspace(0, T - 1, n_keyframes, dtype=int)
    return [all_vels[i] for i in indices]

# %%
# LLM setup

from transformers import Qwen2VLForConditionalGeneration, AutoProcessor
from qwen_vl_utils import process_vision_info

VISION_MODEL_ID = "Qwen/Qwen2-VL-2B-Instruct"

print("Loading vision tokenizer/processor...")
vision_processor = AutoProcessor.from_pretrained(
    VISION_MODEL_ID
)

print("Loading vision model...")
vision_model = Qwen2VLForConditionalGeneration.from_pretrained(
    VISION_MODEL_ID,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

print(f"Vision model loaded on: {vision_model.device}")
print(f"Vision model dtype:     {vision_model.dtype}")
# Out:
# Loading vision tokenizer/processor...
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Loading vision model...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/729 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# Vision model loaded on: cuda:0
# Vision model dtype:     torch.bfloat16

# %%
# Query LLM


def query_vision_llm(prompt_text: str, image_b64: str,
                     max_new_tokens: int = 80) -> str:
  """
  Send a text prompt and a base64 image to the vision LLM.

  Qwen2-VL expects messages in a specific format with image content
  embedded as a base64 data URI inside the content list.
  The processor handles tokenization of both the text and the image tokens.

  Args:
      prompt_text:    the text portion of the prompt
      image_b64:      base64-encoded JPEG string from build_segment_grid_b64
      max_new_tokens: maximum tokens to generate in the response

  Returns:
      decoded response string from the model
  """
  messages = [
    {
      "role": "user",
      "content": [
        {
          "type":     "image",
          "image":    f"data:image/jpeg;base64,{image_b64}",
        },
        {
          "type": "text",
          "text": prompt_text,
        },
      ],
    }
  ]

  # process_vision_info extracts image data from the message format
  # apply_chat_template formats the combined text+image tokens
  text = vision_processor.apply_chat_template(
      messages, tokenize=False, add_generation_prompt=True
  )
  image_inputs, video_inputs = process_vision_info(messages)

  inputs = vision_processor(
      text=[text],
      images=image_inputs,
      videos=video_inputs,
      padding=True,
      return_tensors="pt",
  ).to(vision_model.device)

  input_length = inputs["input_ids"].shape[1]

  with torch.no_grad():
      output_ids = vision_model.generate(
          **inputs,
          max_new_tokens=max_new_tokens,
          do_sample=False,
          temperature=1.0,
          pad_token_id=vision_processor.tokenizer.eos_token_id,
      )

  # decode only newly generated tokens, not the prompt
  generated = output_ids[0][input_length:]
  response  = vision_processor.decode(
      generated, skip_special_tokens=True
  ).strip()

  return response

# %%
VISUAL_PROMPT_STYLES_BY_ENV = {
  "hopper": {
    "visual_minimal": (
        "The image shows two Hopper robot trajectory segments.\n"
        "Row A (top): Segment A across {n_keyframes} keyframes.\n"
        "Row B (bottom): Segment B across {n_keyframes} keyframes.\n"
        "Goal: hop forward while staying balanced and upright.\n"
        "Which segment shows better behavior?"
    ),
    "visual_with_stats": (
        "The image shows two Hopper robot trajectory segments.\n"
        "Row A (top): Segment A. Row B (bottom): Segment B.\n"
        "Goal: hop forward while staying upright.\n"
        "Summary stats:\n{stats_text}\n"
        "Looking at both the images and stats, which segment is better?"
    ),
},
"pendulum": {
    "visual_minimal": (
        "The image shows two Pendulum control segments.\n"
        "Row A (top): Segment A. Row B (bottom): Segment B.\n"
        "Goal: keep the pendulum pointing straight up with minimal swinging.\n"
        "Which segment shows better upright control?"
    ),
    "visual_with_stats": (
        "The image shows two Pendulum control segments.\n"
        "Row A (top): Segment A. Row B (bottom): Segment B.\n"
        "Goal: keep the pendulum upright and still.\n"
        "Summary stats:\n{stats_text}\n"
        "Looking at both the images and stats, which segment is better?"
    ),
},
"ant": {
    "visual_minimal": (
        "The image shows two Ant robot trajectory segments.\n"
        "Row A (top): Segment A. Row B (bottom): Segment B.\n"
        "Goal: move forward efficiently without falling over.\n"
        "Which segment shows better locomotion?"
    ),
    "visual_with_stats": (
        "The image shows two Ant robot trajectory segments.\n"
        "Row A (top): Segment A. Row B (bottom): Segment B.\n"
        "Goal: move forward efficiently without falling.\n"
        "Summary stats:\n{stats_text}\n"
        "Looking at both the images and stats, which segment is better?"
    ),
  },
}

VISUAL_OUTPUT_INSTRUCTION = (
    "\n\nReturn ONLY: the letter A or B, then one short sentence explanation."
)

def _build_minimal_stats_text(seg_a: dict, seg_b: dict) -> str:
  lines = []

  key = "time_upright" if "time_upright" in seg_a else "time_healthy"
  label = "Upright steps" if key == "time_upright" else "Healthy steps"
  lines.append(
      f"{label}: A={seg_a[key]}/{seg_a['segment_length']}, "
      f"B={seg_b[key]}/{seg_b['segment_length']}"
  )

  # forward metric
  if "avg_forward_metric" in seg_a:
      name = seg_a.get("forward_metric_name", "forward")
      lines.append(
          f"Avg {name}: "
          f"A={seg_a['avg_forward_metric']:+.3f}, "
          f"B={seg_b['avg_forward_metric']:+.3f}"
      )

  # fell flag for environments where it applies
  if "fell" in seg_a:
      lines.append(
          f"Fell: A={'yes' if seg_a['fell'] else 'no'}, "
          f"B={'yes' if seg_b['fell'] else 'no'}"
      )

  return "\n".join(lines)

def build_visual_prompt(seg_a: dict, seg_b: dict,
                        env_name: str, style_name: str,
                        n_keyframes: int = 6) -> str:
  styles = VISUAL_PROMPT_STYLES_BY_ENV[env_name]
  if style_name not in styles:
    raise ValueError(
        f"Unknown style name: '{style_name}' for env '{env_name}'. "
        f"Available: {list(styles.keys())}"
    )

  template = styles[style_name]

  if "stats_text" in template:
    stats_text = _build_minimal_stats_text(seg_a, seg_b)
    prompt_body = template.format(
        n_keyframes=n_keyframes, stats_text=stats_text
    )
  else:
    prompt_body = template.format(n_keyframes=n_keyframes)

  return prompt_body + VISUAL_OUTPUT_INSTRUCTION

# %%
def get_llm_preference_visual(seg_a: dict, seg_b: dict,
                               env_name: str, style_name: str,
                               n_keyframes: int = 6,
                               frame_size: tuple = (120, 120)) -> tuple:
    cfg    = ENV_CONFIGS[env_name]
    env_id = cfg["env_id"]

    swap = random.random() < 0.5
    display_first  = seg_a if not swap else seg_b
    display_second = seg_b if not swap else seg_a
    label_map      = {"A": "A", "B": "B"} if not swap else {"A": "B", "B": "A"}

    frames_first  = replay_segment_to_frames(
        env_id, display_first["actions"],  max_frames=n_keyframes
    )
    frames_second = replay_segment_to_frames(
        env_id, display_second["actions"], max_frames=n_keyframes
    )

    keys_first  = select_keyframes(frames_first,  n_keyframes)
    keys_second = select_keyframes(frames_second, n_keyframes)

    # extract velocity values aligned to the keyframes
    vels_first  = extract_keyframe_velocities(display_first,  cfg, n_keyframes)
    vels_second = extract_keyframe_velocities(display_second, cfg, n_keyframes)

    # build grid with velocity overlays
    grid = build_comparison_grid(
        keys_first, keys_second,
        frame_size=frame_size,
        velocities_a=vels_first,    # ← pass velocities
        velocities_b=vels_second,   # ← pass velocities
    )
    b64 = image_to_base64(grid)

    prompt = build_visual_prompt(
        display_first, display_second,
        env_name=env_name, style_name=style_name,
        n_keyframes=n_keyframes
    )

    raw = query_vision_llm(prompt, b64, max_new_tokens=80)

    cleaned        = re.sub(r'\*+([AB])\*+', r'\1', raw, flags=re.IGNORECASE)
    preference_raw, explanation = parse_preference_from_llm(cleaned)
    preference     = label_map.get(preference_raw, "UNCLEAR")

    return preference, explanation, raw

# %%
def training_loop_visual(
    env, cfg, env_name, policy, value_net, reward_model, buffer,
    visual_style_name, n_keyframes=6, frame_size=(120, 120),
    num_rounds=5, rollout_steps=ROLLOUT_STEPS, phase_name='rlhf_visual',
    timestep_offset=0, global_round_offset=0,
    survival_eval_episodes=10, survival_max_steps=None,
):
  history = []

  for round_idx in range(num_rounds):
    # ── collect rollout using current reward model ─────────────────────
    rollout  = collect_rollout(
      env, cfg, policy, value_net,
      reward_model=reward_model, rollout_steps=rollout_steps
    )
    segments = rollout["segments"]

    # ── query vision LLM for preferences ──────────────────────────────
    new_comparisons = 0
    unclear         = 0

    for _ in range(COMPARISONS_PER_ROUND):
      if len(segments) < 2:
        break

      idx_a, idx_b = np.random.choice(
        len(segments), size=2, replace=False
      )
      seg_a = segments[idx_a]
      seg_b = segments[idx_b]

      preference, _, _ = get_llm_preference_visual(
        seg_a, seg_b,
        env_name=env_name,
        style_name=visual_style_name,
        n_keyframes=n_keyframes,
        frame_size=frame_size,
      )

      if preference in ["A", "B"]:
        buffer.add(seg_a, seg_b, preference)
        new_comparisons += 1
      else:
        unclear += 1

    # ── update reward model ────────────────────────────────────────────
    rm_final = None
    if len(buffer) >= 5:
      rm_losses = buffer.train_reward_model(
          reward_model,
          num_epochs=RM_TRAIN_EPOCHS,
          lr=LR_REWARD,
      )
      rm_final = rm_losses[-1] if rm_losses else None

    # ── PPO update ─────────────────────────────────────────────────────
    advantages, returns = compute_gae(
      rollout["rewards"], rollout["values"], rollout["dones"]
    )
    ppo_update(
      policy, value_net,
      rollout["observations"], rollout["actions"],
      rollout["logprobs"], advantages, returns,
    )

    # ── logging ────────────────────────────────────────────────────────
    timestep_end = timestep_offset + (round_idx + 1) * rollout_steps
    row = {
      "env_name":              env_name,
      "prompt_style":          f"visual_{visual_style_name}",
      "phase":                 phase_name,
      "round":                 round_idx + 1,
      "global_round":          global_round_offset + round_idx + 1,
      "timesteps_this_round":  int(rollout_steps),
      "timestep_end":          int(timestep_end),
      "avg_reward_model_score": float(
          np.mean(rollout["rewards"])
      ) if len(rollout["rewards"]) else 0.0,
      "avg_env_reward": float(
          np.mean(rollout["env_rewards"])
      ) if len(rollout["env_rewards"]) else 0.0,
      "segments_collected":    len(segments),
      "new_comparisons":       new_comparisons,
      "unclear_responses":     unclear,
      "buffer_size":           len(buffer),
      "rm_final_loss":         rm_final,
      "n_keyframes":           n_keyframes,
    }

    add_survival_metrics_to_row(
      row, env_name=env_name, env=env, policy=policy,
      survival_eval_episodes=survival_eval_episodes,
      survival_max_steps=survival_max_steps,
    )

    history.append(row)
    print(
      f"Visual round {round_idx + 1}/{num_rounds} — "
      f"style: {visual_style_name} | "
      f"comparisons: {new_comparisons} | "
      f"unclear: {unclear} | "
      f"buffer: {len(buffer)}"
    )

  return history

# %%
print("Testing visual pipeline...")

env_test, cfg_test = make_env("hopper", seed=42)

# collect two real segments to test with
rollout_test = collect_rollout(
    env_test, cfg_test,
    PolicyNetwork(cfg_test["obs_dim"], cfg_test["action_dim"]),
    ValueNetwork(cfg_test["obs_dim"]),
    reward_model=None,
    rollout_steps=200,
    segment_length=50,
)
env_test.close()

assert len(rollout_test["segments"]) >= 2, \
    "Need at least 2 segments for comparison test"

seg_a_test = rollout_test["segments"][0]
seg_b_test = rollout_test["segments"][1]

# test frame rendering
print("Rendering frames from segment A...")
frames_a = replay_segment_to_frames(
    "Hopper-v5", seg_a_test["actions"], max_frames=6
)
print(f"  Got {len(frames_a)} frames, shape: {frames_a[0].shape}")

# test grid building
print("Building comparison grid...")
grid = build_comparison_grid(
    select_keyframes(frames_a, 6),
    select_keyframes(frames_a, 6),   # same segment both rows just for test
    frame_size=(120, 120)
)
print(f"  Grid size: {grid.size}")

# test base64 encoding
b64 = image_to_base64(grid)
print(f"  Base64 length: {len(b64)} chars")

# test visual prompt building
prompt = build_visual_prompt(
    seg_a_test, seg_b_test,
    env_name="hopper",
    style_name="visual_minimal"
)
print(f"\nSample visual prompt:\n{'-'*40}\n{prompt}\n{'-'*40}")

# test full preference query
print("\nQuerying vision LLM...")
preference, explanation, raw = get_llm_preference_visual(
    seg_a_test, seg_b_test,
    env_name="hopper",
    style_name="visual_minimal",
    n_keyframes=6,
)
print(f"  Raw response:  '{raw}'")
print(f"  Preference:    {preference}")
print(f"  Explanation:   {explanation}")

if preference == "UNCLEAR":
    print("  ⚠ UNCLEAR response — check raw output above")
else:
    print(f"  ✓ Got clear preference: {preference}")
# Out:
# Testing visual pipeline...
# Rendering frames from segment A...
#   Got 3 frames, shape: (480, 480, 3)
# Building comparison grid...
#   Grid size: (450, 240)
#   Base64 length: 30528 chars
#
# Sample visual prompt:
# ----------------------------------------
# The image shows two Hopper robot trajectory segments.
# Row A (top): Segment A across 6 keyframes.
# Row B (bottom): Segment B across 6 keyframes.
# Goal: hop forward while staying balanced and upright.
# Which segment shows better behavior?
#
# Return ONLY: the letter A or B, then one short sentence explanation.
# ----------------------------------------
#
# Querying vision LLM...
#   Raw response:  'B. The robot in Segment B shows better behavior as it remains upright and balanced throughout the entire trajectory, while the robot in Segment A shows signs of instability and instability.'
#   Preference:    B
#   Explanation:    The robot in Segment B shows better behavior as it remains upright and balanced throughout the entire trajectory, while the robot in Segment A shows signs of instability and instability.
#   ✓ Got clear preference: B

# %%
# ── Cell: Full visual training run ────────────────────────────────────────────
# Runs warmup with text PPO then RLLF with visual preferences.
# Produces results in the same format as compare_prompt_styles_on_env_reward_with_warmup
# so you can directly compare text vs visual training side by side.

import json

ENV_NAME         = "hopper"
# VISUAL_STYLE     = "visual_minimal"   # or "visual_with_stats"
VISUAL_STYLE     = "visual_with_stats"   # or "visual_with_stats"
WARMUP_ROUNDS    = 8
RLLF_ROUNDS      = 8
ROLLOUT_STEPS_VIS = 3072

set_global_seed(999)
env_vis, cfg_vis = make_env(ENV_NAME, seed=999)

policy_vis       = PolicyNetwork(cfg_vis["obs_dim"], cfg_vis["action_dim"])
value_net_vis    = ValueNetwork(cfg_vis["obs_dim"])
reward_model_vis = RewardModel(cfg_vis["obs_dim"], cfg_vis["action_dim"])
buffer_vis       = ComparisonBuffer()

# ── phase 1: warmup with environment reward ────────────────────────────────
print(f"Env: {ENV_NAME} | Visual style: {VISUAL_STYLE}")
print(f"Phase 1: PPO warm-up ({WARMUP_ROUNDS} rounds)")

warmup_history_vis = training_loop_no_llm(
    env=env_vis, cfg=cfg_vis, policy=policy_vis, value_net=value_net_vis,
    num_rounds=WARMUP_ROUNDS, rollout_steps=ROLLOUT_STEPS_VIS,
    env_name=ENV_NAME, prompt_style=f"visual_{VISUAL_STYLE}",
    phase_name="warmup", timestep_offset=0,
)

# ── phase 2: RLLF with visual preferences ─────────────────────────────────
print(f"\nPhase 2: Visual RLLF ({RLLF_ROUNDS} rounds)")

rlhf_history_vis = training_loop_visual(
    env=env_vis, cfg=cfg_vis, env_name=ENV_NAME,
    policy=policy_vis, value_net=value_net_vis,
    reward_model=reward_model_vis, buffer=buffer_vis,
    visual_style_name=VISUAL_STYLE,
    n_keyframes=12, frame_size=(160, 160),
    num_rounds=RLLF_ROUNDS, rollout_steps=ROLLOUT_STEPS_VIS,
    phase_name="rlhf_visual",
    timestep_offset=WARMUP_ROUNDS * ROLLOUT_STEPS_VIS,
    global_round_offset=WARMUP_ROUNDS,
)

# ── final evaluation ───────────────────────────────────────────────────────
eval_metrics_vis = evaluate_policy_with_env_reward(
    env=env_vis, cfg=cfg_vis, policy=policy_vis,
    value_net=value_net_vis, rollout_steps=ROLLOUT_STEPS_VIS,
    training_env_name=ENV_NAME,
)

env_vis.close()

# ── package results ────────────────────────────────────────────────────────
all_history = warmup_history_vis + rlhf_history_vis
curve_df_vis = pd.DataFrame(all_history)

print("\nVisual RLLF training complete.")
print(f"Final env avg reward: {eval_metrics_vis['env_avg_reward']:.4f}")
print(f"Final avg forward metric: {eval_metrics_vis['avg_forward_metric']:+.4f}")
print(f"Buffer size: {len(buffer_vis)}")
print(f"\nTraining curve shape: {curve_df_vis.shape}")
print(curve_df_vis[["phase", "round", "avg_env_reward",
                     "avg_reward_model_score",
                     "new_comparisons", "unclear_responses"]].to_string())
# Out:
# Env: hopper | Visual style: visual_with_stats
# Phase 1: PPO warm-up (8 rounds)
# Baseline round 1/8 complete
# Baseline round 2/8 complete
# Baseline round 3/8 complete
# Baseline round 4/8 complete
# Baseline round 5/8 complete
# Baseline round 6/8 complete
# Baseline round 7/8 complete
# Baseline round 8/8 complete
#
# Phase 2: Visual RLLF (8 rounds)
# Visual round 1/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 20
# Visual round 2/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 40
# Visual round 3/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 60
# Visual round 4/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 80
# Visual round 5/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 100
# Visual round 6/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 120
# Visual round 7/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 140
# Visual round 8/8 — style: visual_with_stats | comparisons: 20 | unclear: 0 | buffer: 160
#
# Visual RLLF training complete.
# Final env avg reward: 0.8512
# Final avg forward metric: -0.0872
# Buffer size: 160
#
# Training curve shape: (16, 22)
#           phase  round  avg_env_reward  avg_reward_model_score  new_comparisons  unclear_responses
# 0        warmup      1        0.752882                0.752882                0                  0
# 1        warmup      2        0.797664                0.797664                0                  0
# 2        warmup      3        0.794344                0.794344                0                  0
# 3        warmup      4        0.793729                0.793729                0                  0
# 4        warmup      5        0.805528                0.805528                0                  0
# 5        warmup      6        0.945247                0.945247                0                  0
# 6        warmup      7        0.863644                0.863644                0                  0
# 7        warmup      8        0.820871                0.820871                0                  0
# 8   rlhf_visual      1        0.776026               -0.128962               20                  0
# 9   rlhf_visual      2        0.931911                0.098068               20                  0
# 10  rlhf_visual      3        0.788643               -0.024231               20                  0
# 11  rlhf_visual      4        0.881725                0.013183               20                  0
# 12  rlhf_visual      5        0.850341               -0.083557               20                  0
# 13  rlhf_visual      6        0.841983               -0.207866               20                  0
# 14  rlhf_visual      7        0.801397               -0.381522               20                  0
# 15  rlhf_visual      8        0.759536               -0.354772               20                  0
